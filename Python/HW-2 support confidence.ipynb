# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth

# %%
dataset = [['a', 'd', 'e',],
           ['a', 'b', 'c', 'e'],
           ['a', 'b', 'd', 'e'],
           ['a', 'c', 'd', 'e'],
           ['b', 'c', 'e'],
           ['b', 'd', 'e'],
           ['c', 'd'],
           ['a', 'b', 'c'],
           ['a', 'd', 'e'],
           ['a', 'b', 'e']]

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = fpgrowth(df, min_support=0.16, use_colnames=True)

# %%
frequent_itemsets
# Out:
#     support   itemsets
# 0       0.8        (e)
# 1       0.7        (a)
# 2       0.6        (d)
# 3       0.6        (b)
# 4       0.5        (c)
# 5       0.6     (a, e)
# 6       0.5     (e, d)
# 7       0.4     (a, d)
# 8       0.4  (e, a, d)
# 9       0.5     (b, e)
# 10      0.4     (b, a)
# 11      0.2     (b, d)
# 12      0.3  (b, a, e)
# 13      0.2  (b, e, d)
# 14      0.3     (c, b)
# 15      0.3     (c, a)
# 16      0.3     (c, e)
# 17      0.2     (c, d)
# 18      0.2  (c, b, a)
# 19      0.2  (c, a, e)
# 20      0.2  (c, b, e)

# %%
from mlxtend.frequent_patterns import association_rules

association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0          (a)         (e)                 0.7                 0.8      0.6
# 1          (e)         (a)                 0.8                 0.7      0.6
# 2          (e)         (d)                 0.8                 0.6      0.5
# 3          (d)         (e)                 0.6                 0.8      0.5
# 4          (a)         (d)                 0.7                 0.6      0.4
# 5          (d)         (a)                 0.6                 0.7      0.4
# 6       (a, e)         (d)                 0.6                 0.6      0.4
# 7       (d, e)         (a)                 0.5                 0.7      0.4
# 8       (a, d)         (e)                 0.4                 0.8      0.4
# 9          (e)      (a, d)                 0.8                 0.4      0.4
# 10         (a)      (d, e)                 0.7                 0.5      0.4
# 11         (d)      (a, e)                 0.6                 0.6      0.4
# 12         (b)         (e)                 0.6                 0.8      0.5
# 13         (e)         (b)                 0.8                 0.6      0.5
# 14         (b)         (a)                 0.6                 0.7      0.4
# 15         (a)         (b)                 0.7                 0.6      0.4
# 16         (b)         (d)                 0.6                 0.6      0.2
# 17         (d)         (b)                 0.6                 0.6      0.2
# 18      (b, a)         (e)                 0.4                 0.8      0.3
# 19      (b, e)         (a)                 0.5                 0.7      0.3
# 20      (a, e)         (b)                 0.6                 0.6      0.3
# 21         (b)      (a, e)                 0.6                 0.6      0.3
# 22         (a)      (b, e)                 0.7                 0.5      0.3
# 23         (e)      (b, a)                 0.8                 0.4      0.3
# 24      (b, e)         (d)                 0.5                 0.6      0.2
# 25      (b, d)         (e)                 0.2                 0.8      0.2
# 26      (d, e)         (b)                 0.5                 0.6      0.2
# 27         (b)      (d, e)                 0.6                 0.5      0.2
# 28         (e)      (b, d)                 0.8                 0.2      0.2
# 29         (d)      (b, e)                 0.6                 0.5      0.2
# 30         (c)         (b)                 0.5                 0.6      0.3
# 31         (b)         (c)                 0.6                 0.5      0.3
# 32         (c)         (a)                 0.5                 0.7      0.3
# 33         (a)         (c)                 0.7                 0.5      0.3
# 34         (c)         (e)                 0.5                 0.8      0.3
# 35         (e)         (c)                 0.8                 0.5      0.3
# 36         (c)         (d)                 0.5                 0.6      0.2
# 37         (d)         (c)                 0.6                 0.5      0.2
# 38      (c, b)         (a)                 0.3                 0.7      0.2
# 39      (c, a)         (b)                 0.3                 0.6      0.2
# 40      (b, a)         (c)                 0.4                 0.5      0.2
# 41         (c)      (b, a)                 0.5                 0.4      0.2
# 42         (b)      (c, a)                 0.6                 0.3      0.2
# 43         (a)      (c, b)                 0.7                 0.3      0.2
# 44      (c, a)         (e)                 0.3                 0.8      0.2
# 45      (c, e)         (a)                 0.3                 0.7      0.2
# 46      (a, e)         (c)                 0.6                 0.5      0.2
# 47         (c)      (a, e)                 0.5                 0.6      0.2
# 48         (a)      (c, e)                 0.7                 0.3      0.2
# 49         (e)      (c, a)                 0.8                 0.3      0.2
# 50      (c, b)         (e)                 0.3                 0.8      0.2
# 51      (c, e)         (b)                 0.3                 0.6      0.2
# 52      (b, e)         (c)                 0.5                 0.5      0.2
# 53         (c)      (b, e)                 0.5                 0.5      0.2
# 54         (b)      (c, e)                 0.6                 0.3      0.2
# 55         (e)      (c, b)                 0.8                 0.3      0.2
#
#     confidence      lift  leverage  conviction
# 0     0.857143  1.071429      0.04    1.400000
# 1     0.750000  1.071429      0.04    1.200000
# 2     0.625000  1.041667      0.02    1.066667
# 3     0.833333  1.041667      0.02    1.200000
# 4     0.571429  0.952381     -0.02    0.933333
# 5     0.666667  0.952381     -0.02    0.900000
# 6     0.666667  1.111111      0.04    1.200000
# 7     0.800000  1.142857      0.05    1.500000
# 8     1.000000  1.250000      0.08         inf
# 9     0.500000  1.250000      0.08    1.200000
# 10    0.571429  1.142857      0.05    1.166667
# 11    0.666667  1.111111      0.04    1.200000
# 12    0.833333  1.041667      0.02    1.200000
# 13    0.625000  1.041667      0.02    1.066667
# 14    0.666667  0.952381     -0.02    0.900000
# 15    0.571429  0.952381     -0.02    0.933333
# 16    0.333333  0.555556     -0.16    0.600000
# 17    0.333333  0.555556     -0.16    0.600000
# 18    0.750000  0.937500     -0.02    0.800000
# 19    0.600000  0.857143     -0.05    0.750000
# 20    0.500000  0.833333     -0.06    0.800000
# 21    0.500000  0.833333     -0.06    0.800000
# 22    0.428571  0.857143     -0.05    0.875000
# 23    0.375000  0.937500     -0.02    0.960000
# 24    0.400000  0.666667     -0.10    0.666667
# 25    1.000000  1.250000      0.04         inf
# 26    0.400000  0.666667     -0.10    0.666667
# 27    0.333333  0.666667     -0.10    0.750000
# 28    0.250000  1.250000      0.04    1.066667
# 29    0.333333  0.666667     -0.10    0.750000
# 30    0.600000  1.000000      0.00    1.000000
# 31    0.500000  1.000000      0.00    1.000000
# 32    0.600000  0.857143     -0.05    0.750000
# 33    0.428571  0.857143     -0.05    0.875000
# 34    0.600000  0.750000     -0.10    0.500000
# 35    0.375000  0.750000     -0.10    0.800000
# 36    0.400000  0.666667     -0.10    0.666667
# 37    0.333333  0.666667     -0.10    0.750000
# 38    0.666667  0.952381     -0.01    0.900000
# 39    0.666667  1.111111      0.02    1.200000
# 40    0.500000  1.000000      0.00    1.000000
# 41    0.400000  1.000000      0.00    1.000000
# 42    0.333333  1.111111      0.02    1.050000
# 43    0.285714  0.952381     -0.01    0.980000
# 44    0.666667  0.833333     -0.04    0.600000
# 45    0.666667  0.952381     -0.01    0.900000
# 46    0.333333  0.666667     -0.10    0.750000
# 47    0.400000  0.666667     -0.10    0.666667
# 48    0.285714  0.952381     -0.01    0.980000
# 49    0.250000  0.833333     -0.04    0.933333
# 50    0.666667  0.833333     -0.04    0.600000
# 51    0.666667  1.111111      0.02    1.200000
# 52    0.400000  0.800000     -0.05    0.833333
# 53    0.400000  0.800000     -0.05    0.833333
# 54    0.333333  1.111111      0.02    1.050000
# 55    0.250000  0.833333     -0.04    0.933333
